# %% [markdown]
# # Simple Linear Regression
#
# > Tutorials/Instructions I followed:
# > - [Campus X](https://www.youtube.com/playlist?list=PLKnIA16_Rmva-wY_HBh1gTH32ocu2SoTr)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
class LinearRegression:
    def __init__(self):
        self.m = None # slope/coefficient
        self.b = None # intercept

    def fit(self, X_train, y_train):
        num, den = 0, 0
        for i in range(X_train.shape[0]):
            num = num + (X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean())
            den = den + (X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean())

        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())

        print(f"Model trained with m: {self.m}, b: {self.b}")

    def predict(self, X_test):
        return self.m * X_test + self.b

# %%
file_path = Path().resolve().parent / '.data/placement.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# # Visualizations

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.show()

# %%
X = df.iloc[:, 0].values
y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# Model trained with m: 0.5579519734250721, b: -0.8961119222429152

# %%
model.predict(X_test[0])
# Out:
# np.float64(3.891116009744203)
